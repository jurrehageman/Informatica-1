# %% [markdown]
# ### Seminar 03: Reading and writing files

# %% [markdown]
# ## Introduction

# %% [markdown]
# Author: Jurre Hageman

# %% [markdown]
# For this lesson, you will learn to read and write files with Python.
# We will end the lesson with a program that will read a file with DNA sequences, calculates the GC percentage and store the highest GC percentage to a file.

# %% [markdown]
# ## Print message to the screen

# %% [markdown]
# Create two variables that store your first name and last name. Print them using the print function after the message "Hello". The output should be like: Hello Jan Janssen.
# Use IDLE3 to write this script.

# %%
# generate two variables below: firstname and lastname. Print your name.

# firstname =
firstname = "Jurre"
# lastname =
lastname = "Hageman"
# print to screen
print(firstname, lastname)
# Out:
# Jurre Hageman

# %% [markdown]
# Nice work! Next we will write some code to print multiple items using a loop.
# There are different types of loops. We will explore a for loop in the next section.
# The for loop in Python is used to avoid repetition of code.
# Suppose we have a collection of different items stored. We can store them in a list:

# %%
items = ["This", "is", "a", "list", "with", "each", "item", "being", "a", "string"]
#now print the list to the screen:
print(items)
# Out:
# ['This', 'is', 'a', 'list', 'with', 'each', 'item', 'being', 'a', 'string']

# %% [markdown]
# A text file is also a collection of items. It is a collection of lines containing characters.
# To loop through the collection we can use a for loop. Each item will be printed:

# %%
items = ["This", "is", "a", "list", "with", "each", "item", "being", "a", "string"]
#use a for loop to print each item to the screen
for item in items:
    print(item)
# Out:
# This
# is
# a
# list
# with
# each
# item
# being
# a
# string

# %% [markdown]
# Item is now a placeholder that is overwritten for each consecutive loop. The first loop item refers to "This", the second loop to "is" etc.
# Note that item (singular) differs from items (plural). Items refers to the complete list while item is the placeholder in the for loop refering to each item of the list.

# %% [markdown]
# ## Read a file

# %% [markdown]
# The next thing we would like to do is to open a file.
# We have a text file in the directory that is named "input.txt". Make sure that you download this file in your working directory (the same directory in which you store your python file).
# Before we can read a file, we should make a file object.

# %%
#create a variable with the file name
file_name = "input.txt"
#create a variable of a file object in read mode
file_object = open(file_name)
#print the file object
print(file_object)
# Out:
# <_io.TextIOWrapper name='input.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# Printing the file object gives a bit of intimidating result. Do not let it intimidate you. It's just a file object in read mode with a certain encoding that can display the content.
# To display the content we can loop through the file object in the following manner:

# %%
#create a variable with the file name
file_name = "input.txt"
#create a variable of a file object in read mode
my_file = open(file_name)
#loop to the lines and display the contents of the file
for line in my_file:
    print(line)
#close the file object
my_file.close()
# Out:
# This is a text files.
#
# It has multiple lines...
#
# but not a very interesting content.
#
# End of message.

# %% [raw]
# The keyword "line" is now a placeholder for every line of the file. The first loop it refers to the first line, the second loop to the second.
# Note that a line break is introduced between each line. This is caused by the print function which normally introduces a line break after each printing event. This can be avoided by stripping the empty space (including newlines) from the lines.

# %%
mssg1 = "Hello\n"
mssg2 = "How are you?"
#strip the whitespace and print
print(mssg1.strip())
print(mssg2)
# Out:
# Hello
# How are you?

# %% [markdown]
# Now open the file exercise2.txt and assign it to a variable.
# Use a for loop to loop throug each line. Avoid linebreaks between the lines using the strip method.

# %%
#write your script here
file_name = "excercise2.txt"
file_obj = open(file_name)
for line in file_obj:
    print(line.strip())
file_obj.close()
# Out:
# In number theory, a weird number is a natural number that is abundant but not semiperfect.
# In other words, the sum of the proper divisors (divisors including 1 but not itself) of the number is greater than the number,
# but no subset of those divisors sums to the number itself.
#
# The smallest weird number is 70.
# Its proper divisors are 1, 2, 5, 7, 10, 14, and 35;
# these sum to 74, but no subset of these sums to 70.
# The number 12, for example, is abundant but not weird,
# because the proper divisors of 12 are 1, 2, 3, 4, and 6,
# which sum to 16; but 2+4+6 = 12.
#
# Source: Wikipedia.org

# %% [markdown]
# ## Write to a file

# %% [markdown]
# Well done!
# So far we have opened a file and displayed its content.
# You may also want to write something to a file.
# You can use the print function to write lines to a file.
#
# Write code below using the help function that explores the print function.

# %%
print(help(print))
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.
#
# None

# %% [markdown]
# File objects are in 3 modi:
# - read ("r")
# - write ("w")
# - append ("a")
# Create a variable holding a file name below
# Create a file object in write modus and write something to the file
# Do not forget to close the file object

# %%
#create a file "output2.txt" and write content to it.
file_name = "output2.txt"
output_file_obj = open(file_name, "w")
print("Hello World!", file=output_file_obj)
output_file_obj.close()

# %% [markdown]
# Now open the file and read the content

# %%
#open the file and read the content
read_file_name = "output2.txt"
read_file_obj = open(read_file_name)
for l in read_file_obj:
    print(l.strip())
read_file_obj.close()
# Out:
# Hello World!

# %% [markdown]
# ## Write in append mode

# %% [markdown]
# It is also possible to append files with new text. You can do this by writing to the file in append mode ("a").
# Append a new line of text to output2.txt.

# %%
#write a new line to output2.txt in append mode
file_name = "output2.txt"
file_obj = open(file_name, "a")
print("a new line", file=file_obj)
file_obj.close()

# %% [markdown]
# Now open the file and see if the line was added to the excisting file:

# %%
#open the file and see if the new line is added
file_obj = open("output2.txt")
for line in file_obj:
    print(line.strip())
file_obj.close()
# Out:
# Hello World!
# een nieuwe regel
# a new line

# %% [markdown]
# ## GC percentage calculator

# %% [markdown]
# As a final excersise, write a script that:
# - opens a text file
# - for each line of DNA nucleotides calculates the GC percentage and prints it.
# - remembers the DNA sequence with the highest GC percentage
# - writes the DNA sequence with the highest GC percentage as well as the percentage to a file.

# %%
#write your script here

file_name = "input_sequence.txt"
file_name_output = "output_gc_content.txt"
file_obj = open(file_name)
GC_max = 0 #set variable GC max to 0
highest_GC_sequence = "" #this is set to an empty string

for line in file_obj:
    line = line.strip()
    G = line.count("G")
    C = line.count("C")
    GC = G + C
    perc_GC = GC / len(line) * 100
    perc_GC = round(perc_GC)
    print("processing", line, ", GC percentage:", perc_GC)
    if perc_GC > GC_max: #if the percentage is the highest
        GC_max = perc_GC #overwrite the highscore
        highest_GC_sequence = line #overwrite the sequence with the highest GC
        print("New record, highest GC sequence is:", highest_GC_sequence)
        print("New record, highest GC percentage:", GC_max)
file_obj.close() #close the file
print() #print empty line
print("The sequence with the highest GC value is:", highest_GC_sequence)
print("The Highest GC percentage is:", GC_max)

file_obj_out = open(file_name_output, "w")
print("The sequence with the highest GC value is:", highest_GC_sequence, file=file_obj_out)
print("The Highest GC percentage is:", GC_max, file=file_obj_out)
file_obj_out.close() #do not forget to close the file object!
print("Data written to:", file_name_output)
# Out:
# processing GAAACAATCCGAAGACAACA , GC percentage: 40
# New record, highest GC sequence is: GAAACAATCCGAAGACAACA
# New record, highest GC percentage: 40
# processing GCGGGGAAACAACATAGAGT , GC percentage: 50
# New record, highest GC sequence is: GCGGGGAAACAACATAGAGT
# New record, highest GC percentage: 50
# processing GAGACGGCATTTCCGCCACT , GC percentage: 60
# New record, highest GC sequence is: GAGACGGCATTTCCGCCACT
# New record, highest GC percentage: 60
# processing ACCCCTCAGATGTTATTGAA , GC percentage: 40
# processing CAGAGCAGTTCTTTGCGGAA , GC percentage: 50
# processing TCGACCATAACTTACGGATA , GC percentage: 40
# processing GCATTCCCACCGGGGGCGGT , GC percentage: 75
# New record, highest GC sequence is: GCATTCCCACCGGGGGCGGT
# New record, highest GC percentage: 75
# processing TTAGGCACGTTCGAGCTGAA , GC percentage: 50
# processing AGCTCTTCCGGTACAGTGAT , GC percentage: 50
# processing CAGCTATTAGTTGCGTTAGT , GC percentage: 40
# processing GTCATGGTAATTTCGTTCAC , GC percentage: 40
# processing ATGTTAAAGAACCACGATCT , GC percentage: 35
# processing CCGCCTGTCTCTCATACTTG , GC percentage: 55
# processing GCTTGGATTCGGGGTGACTC , GC percentage: 60
# processing TTTGTTATCATGAATCCCAC , GC percentage: 35
# processing GACTCTCATGAGGCTGTTAT , GC percentage: 45
# processing GAGCCCGTGAGACGGTTTGA , GC percentage: 60
# processing TCTCCGCAAGATTATGGGCC , GC percentage: 55
# processing TATTCCTTCGCATGCGAGCC , GC percentage: 55
# processing ATGACAATGTCAAATCATCC , GC percentage: 35
# processing AATTCGTCCAGTAGGGCGGA , GC percentage: 55
# processing GTACCCTACCGAATGAATGT , GC percentage: 45
# processing TTCGCAGGTGACAGGACTAA , GC percentage: 50
# processing GCCTCGCTACGCGTTAGGAC , GC percentage: 65
# processing CTTAGCAAACCCTGTCACAT , GC percentage: 45
# processing CAGTCTGCCGTTAAATGTGG , GC percentage: 50
# processing GCCTGCGCGGACGTACCACT , GC percentage: 70
# processing CGCAACTGCTTGGCTAAGAT , GC percentage: 50
# processing TGCTTTTTTCATAGTACCAC , GC percentage: 35
# processing TCGCGCGTATGTGCCGTGCA , GC percentage: 65
# processing GTTGTTAGTCTTTCGTGTGT , GC percentage: 40
# processing TCAACGACGCTCTTTAACCC , GC percentage: 50
# processing TAGGTTTTTGGTTCTTGTCA , GC percentage: 35
# processing CTCTACGCGTCAAAGAGCGT , GC percentage: 55
# processing GACTACACAGGGTGGGCGTA , GC percentage: 60
# processing GAAGAGAGGCCAGGTAGATC , GC percentage: 55
# processing AATGCTAATTATACCAGCTA , GC percentage: 30
# processing TGACACAAGGACAAGAACTA , GC percentage: 40
# processing CTACCCGCTCTGAAACCGAA , GC percentage: 55
# processing GACGGCGATTGACCTTTTTA , GC percentage: 45
# processing GACCGGAGATAGGACTCGCT , GC percentage: 60
# processing TAGCGCATACTGCGAATGTG , GC percentage: 50
# processing CTTCGCAGAGCTTCGACCAC , GC percentage: 60
# processing CGACTAGTCTCTGCAAATCC , GC percentage: 50
# processing TGTGAAAGCCGTTTCCACTC , GC percentage: 50
# processing TATCCATCAGCGGGTATGAC , GC percentage: 50
# processing CAGTGAGGATAAACAATGAG , GC percentage: 40
# processing GGGCCCGATGATAAGATCCA , GC percentage: 55
# processing CGTCATGCTGTATAATGGAT , GC percentage: 40
# processing TAAGCGTCTCGCCAGTTACG , GC percentage: 55
# processing TTCGCAACTCTTACGAATCA , GC percentage: 40
# processing CGTTTTTGTGTATGAATGCT , GC percentage: 35
# processing CAGCACGATTAGCTATACCA , GC percentage: 45
# processing CTGGAAAGCTGAATCCTGAG , GC percentage: 50
# processing ATGGGTTTCGAGTCGGTTAG , GC percentage: 50
# processing CCCGGGTGTGCGCGAGAGAA , GC percentage: 70
# processing CGGTGGGGCCAACAATCTCT , GC percentage: 60
# processing TGCGATCACGGCTGCAATGA , GC percentage: 55
# processing CAAAGTGAAGGGAGTACACC , GC percentage: 50
# processing TAGTACTACTAGAGTCGTCC , GC percentage: 45
# processing TCCGAATTCAGAGAGCGACC , GC percentage: 55
# processing GAAAAATAAGACCGCCCATC , GC percentage: 45
# processing CCTTAAAAGCCGGATCTTTC , GC percentage: 45
# processing TCTGGGGCTTAATGCAATGG , GC percentage: 50
# processing GATGCCGCCAGGATGGATAC , GC percentage: 60
# processing CATGATTTTGACGTTTTTAC , GC percentage: 30
# processing GTCGTGATTGCTTATGGCTC , GC percentage: 50
# processing GCCCGTCTGTGCTTCAAATA , GC percentage: 50
# processing AGGAGCAACATTGGCAGGCC , GC percentage: 60
# processing TTCCCTAATAACATGTTCAG , GC percentage: 35
# processing AAAATTGGCAGAGTGATTGG , GC percentage: 40
# processing TGCACCGGAGTGACAGTAAT , GC percentage: 50
# processing CATGTGGCTAGAGGGTCATC , GC percentage: 55
# processing ATATTAGGCCGCCCTCTAAG , GC percentage: 50
# processing ATTCATAGGGCATGTGCCCC , GC percentage: 55
# processing CGGGCGTCCGCAGTAAATCG , GC percentage: 65
# processing CGCTGTGCGAAGATGACTCT , GC percentage: 55
# processing ACCCGAATCCAGACCGAGAG , GC percentage: 60
# processing GTCTTCACCCCTGGAACAAA , GC percentage: 50
# processing CAGTCTGAGACATGGTTCCA , GC percentage: 50
# processing GTCCACGATCTTTATCCGGA , GC percentage: 50
# processing CCGACATACCAATCAGGTTC , GC percentage: 50
# processing TGGGAAAAAGGAGCAAATCG , GC percentage: 45
# processing TTTCGGTCACGGGCTCACCG , GC percentage: 65
# processing ACGACGCGTACAGGATGTAA , GC percentage: 50
# processing CTTAAAGGAGTGTCCACCCG , GC percentage: 55
# processing AAGTGCTCTGACGTTGGCCG , GC percentage: 60
# processing GAATTGTAGAGCAGTCTAGT , GC percentage: 40
# processing TTGGCTATAGCATGCTCTTG , GC percentage: 45
# processing ACGTGCCATAGGGGCTATAA , GC percentage: 50
# processing TTCGTAGCCAGAGTACCTTG , GC percentage: 50
# processing TTGCATAATACATAACTGTT , GC percentage: 25
# processing TAACACAATATAAAAGGATT , GC percentage: 20
# processing CATTCTACTGAACGGAACCG , GC percentage: 50
# processing AAGGTTGTGGAAAAGTGTTG , GC percentage: 40
# processing GAAATGGACCTGGCTCCATG , GC percentage: 55
# processing CCTCAGGAAGACCGCTGATT , GC percentage: 55
# processing CCTCCACGGCGCTAACTAAC , GC percentage: 60
# processing TTCTTTATCGCTGGGAACCC , GC percentage: 50
# processing AAAATCTGTCCGCAAGCATT , GC percentage: 40
# processing TATTCGAACCGCCAAGGAGA , GC percentage: 50
# processing GTCCGGACTGACGCATATCT , GC percentage: 55
# processing AAGAGTGCGGTTGAAGCTTT , GC percentage: 45
# processing AGCGCTTGGTCATCCGTTGA , GC percentage: 55
# processing CATTTTGCACAGCGTTCGGA , GC percentage: 50
# processing GCATGTAGTATCACAAGGTC , GC percentage: 45
# processing GTCCGTCCTAGATCACGTAC , GC percentage: 55
# processing CTTTAGCAGCGTCCTTCGAT , GC percentage: 50
# processing CGAGTTCCGTGACCTTAGGC , GC percentage: 60
# processing ACACAGTCGCAACTCATATA , GC percentage: 40
# processing TTCCGCTGAAATAACTGAAT , GC percentage: 35
# processing AGCGGGTGCCCATCAGACCA , GC percentage: 65
# processing TTGTTTAGTATAGTTGATGT , GC percentage: 25
# processing GGTTAGACCCGGCAATAGAA , GC percentage: 50
# processing GCATCGGAAGCCTTATCTTA , GC percentage: 45
# processing CAACCAGTTCCACAGGGCTA , GC percentage: 55
# processing GCCCCCTCCTGCGTACCCGT , GC percentage: 75
# processing CCAAAGTAGCCGTTAAAAGC , GC percentage: 45
# processing ATATGGTACTGTGTGGAGTT , GC percentage: 40
# processing GTGAATTAAAACCGTTTTAG , GC percentage: 30
# processing GTCGGTAACGATCATTCTTG , GC percentage: 45
# processing TCGAGGCACCTCGTATGGTG , GC percentage: 60
# processing CAAGAGCGGTGACATGAAGG , GC percentage: 55
# processing CATTGCACTCGTTTCCCTCT , GC percentage: 50
# processing GATGAGAAGGGTTGCGCATA , GC percentage: 50
# processing CTAGCAATAGTACGGTGCAC , GC percentage: 50
# processing GGATTAAAAGCCTTTTTAAT , GC percentage: 25
# processing AATGTTCTACCGATGGGCCT , GC percentage: 50
# processing CCAGAGATCTGCCTCTGCGG , GC percentage: 65
# processing GAAGGACAACAACCGCTCAG , GC percentage: 55
# processing GCCCGGCGCGTCTCACAGCT , GC percentage: 75
# processing TGTGCGCCATCCCAAACTTG , GC percentage: 55
# processing GATCCCAGAAGTCTCGTTAT , GC percentage: 45
# processing TGTGAGCTATCGACATGATA , GC percentage: 40
# processing TATATTCAACCCACGAGGTA , GC percentage: 40
# processing CCACTTCAAAGGGGCAGGGA , GC percentage: 60
# processing TAGTTTCATCAGGATAGTGA , GC percentage: 35
# processing TCATGTCTCGCACCTCAGCG , GC percentage: 60
# processing CTCGTCCTCGCCCCAATATT , GC percentage: 55
# processing TGATGGGCTACCGTCCAGTT , GC percentage: 55
# processing GGGGATCGCGCGCATCCGCG , GC percentage: 80
# New record, highest GC sequence is: GGGGATCGCGCGCATCCGCG
# New record, highest GC percentage: 80
# processing ACGCAACACGCGCTACCGTG , GC percentage: 65
# processing TATGGTAGGTCAGCAGTTCA , GC percentage: 45
# processing CTATAAGTCTGCGCTCCCCC , GC percentage: 60
# processing GTAAATGTACAGTACTCGGG , GC percentage: 45
# processing GGAAGTCAGCTCTTTTCTTG , GC percentage: 45
# processing TTGCGCCCTTTCCACTAGCT , GC percentage: 55
# processing GCATTTTGAGTAGGGGTTAG , GC percentage: 45
# processing GATCATTCCCCGATAAGTTC , GC percentage: 45
# processing GTCTAGCCTACGCAACGTTG , GC percentage: 55
# processing GGCGCGAAAAGGCATAATTA , GC percentage: 45
# processing ACGCTATCCAACGCCAAGGA , GC percentage: 55
# processing GAGGCTGCAGGTCGATGCAT , GC percentage: 60
# processing CGGGCAGTACTGACATGGAT , GC percentage: 55
# processing AAAGGGTCGAGGTTGTCACA , GC percentage: 50
# processing TCTTCACTAGGGAAGGTGGT , GC percentage: 50
# processing TAACAGAGCGAACCTTTCAC , GC percentage: 45
# processing ATTAGTCCGTGCATCCAGAC , GC percentage: 50
# processing TAATCTTACAGCCGCTCCGA , GC percentage: 50
# processing CGGATTCCTATCGCATTGAG , GC percentage: 50
# processing GTTGAGTCAAGCGGTTCGTG , GC percentage: 55
# processing TCACAATTTTGATCAGTAGA , GC percentage: 30
# processing GGAGGCAATAGTGACAGGGC , GC percentage: 60
# processing AGCGTCAAAGCGTCCTCTCC , GC percentage: 60
# processing CCCTCACCGTTTTATGAAGC , GC percentage: 50
# processing GTAGTGTATAACAGTGAGGA , GC percentage: 40
# processing TAACGTCTACGAGTTGCTCT , GC percentage: 45
# processing TACTTCTATGTGGTCAAGCC , GC percentage: 45
# processing CCCGTCGCGATCAAGAAATG , GC percentage: 55
# processing ACGCATGTGGGATGGTCGCA , GC percentage: 60
# processing CTGCGAGGCCCTGAATCTCC , GC percentage: 65
# processing TTTCCTACAGCCGCCTTGCC , GC percentage: 60
# processing CCAGCTTTAAGAATCTGGCC , GC percentage: 50
# processing CACACCTACATCTGCCGGCA , GC percentage: 60
# processing GTGACCAGTGTTGCATTAGG , GC percentage: 50
# processing GCTTATGTGTGCGCCCTCGA , GC percentage: 60
# processing GGCCGGGTCACGGCTGGCAG , GC percentage: 80
# processing ATGCATCGATAGCCTTGTCC , GC percentage: 50
# processing CCGTATGGAGTGACAGGTTG , GC percentage: 55
# processing GGTCGTGCAATACTCAGCAC , GC percentage: 55
# processing TACTGGCGAGATGCGTCTTT , GC percentage: 50
# processing CTTTAGTCGGCTACCGTAAT , GC percentage: 45
# processing GTCACTCACGTGGCTGTTGC , GC percentage: 60
# processing TTGCCTCGCACCGAAGAGTC , GC percentage: 60
# processing GGTTACCACCCTAAGCGCGC , GC percentage: 65
# processing ACCTAGGTGGGGGTCCAGCT , GC percentage: 65
# processing TAAATTGTGCAGATGAAAAT , GC percentage: 25
# processing AGATGCAAGCGAGGCTAATA , GC percentage: 45
# processing GAAACAATGGACCCAAGTCA , GC percentage: 45
# processing ACAAGTACCTTGAGAGCATT , GC percentage: 40
# processing TCCCACCAGAGTACGTTCGA , GC percentage: 55
# processing TTATCGCTGTGTCATAGAGC , GC percentage: 45
# processing TGTCGGTTTGATCACCCAGT , GC percentage: 50
# processing CTGACAGTTCTAAAGGACAT , GC percentage: 40
# processing AACCTCTAGAACGGGGAAAA , GC percentage: 45
# processing TCAGTTAGGACAACATGCGC , GC percentage: 50
# processing GATGTTTCATGAACACGAAG , GC percentage: 40
# processing ATAGTCCAAGCGCCGCCACT , GC percentage: 60
# processing ATCGCCAGTGCTCGTAGCCG , GC percentage: 65
# processing ACAGCTCGTCGCCATCAAGT , GC percentage: 55
# processing CGAAACTCTGGTCGGTACCT , GC percentage: 55
# processing CTTCGGTATCGCGGTCTCCA , GC percentage: 60
# processing TGGAGTAATGTGGGAATGGG , GC percentage: 50
# processing ACTTGCGCACATTCGTCGCT , GC percentage: 55
# processing GGGAATGTCAAACGAATGCT , GC percentage: 45
# processing TGATAGAATTGATGGAAGAG , GC percentage: 35
# processing TAGACTCCGGGGCTGTCCCA , GC percentage: 65
# processing CGACAGAATTTCCTTTGCAA , GC percentage: 40
# processing ACATTGACGGGAAGTCATTC , GC percentage: 45
# processing TGATTCTCTTGCTAACATTG , GC percentage: 35
# processing ACTCACACGTAATTTGTAAA , GC percentage: 30
# processing CCTCCCGCTTGCCCTACCAT , GC percentage: 65
# processing ATACCAGTGCTCCAGGTTGT , GC percentage: 50
# processing CTAGTGGGAAGACCTCTATT , GC percentage: 45
# processing CATCTAGAAAGTGCTATTCG , GC percentage: 40
# processing TGATCGCAACCACTCCGTGC , GC percentage: 60
# processing GCGGCCATTGTCCATGCCTT , GC percentage: 60
# processing GGAATAGCGGCCCCTCGCAC , GC percentage: 70
# processing CTTGTGCCGAAGCCTCCCCT , GC percentage: 65
# processing AGTGAATTTTGCAAGAATAC , GC percentage: 30
# processing AGGGTGTGTCGGGTTTTAAA , GC percentage: 45
# processing ATTGGCTTGGATGTAGTGCA , GC percentage: 45
# processing TTCAATATCAGATTTGTACT , GC percentage: 25
# processing CAATGCATCGACTAACGTAT , GC percentage: 40
# processing CCGAGCAAGCGTGATTCCTT , GC percentage: 55
# processing CTTATCAAACCCAAACTCGT , GC percentage: 40
# processing TAATTCGTGATCCTCGACGA , GC percentage: 45
# processing GAGGCTTGACAAATTATGTT , GC percentage: 35
# processing TTCTTTGCGTCGCGTACCCA , GC percentage: 55
# processing CCTCGTTTGTATTTCACACT , GC percentage: 40
# processing GGGGCCCGGTGCCAGGGCGG , GC percentage: 90
# New record, highest GC sequence is: GGGGCCCGGTGCCAGGGCGG
# New record, highest GC percentage: 90
# processing TCTTCAGTCCACTAATGATG , GC percentage: 40
# processing CAGGAACAATGGTTACGTAC , GC percentage: 45
# processing CATGACTACGTTGCTCATGA , GC percentage: 45
# processing GTTCCAGAAGGTATAGTGAG , GC percentage: 45
# processing CGCTAAACCTGTGTCAACCC , GC percentage: 55
# processing CCAAACCATTTGAGCCGGGG , GC percentage: 60
# processing GATTACTATGGCGCGGTGCA , GC percentage: 55
# processing TTCACAACCTAATTTTGTCG , GC percentage: 35
# processing GTTACTTCGATCCGTTGCTG , GC percentage: 50
# processing GATGGCCGGAGGTTACATAT , GC percentage: 50
# processing TGAACGAAAGCATGCACCGT , GC percentage: 50
# processing CTCTTCTCTGGTGTTCGGAA , GC percentage: 50
# processing ACAGTCTAGGCCGGCAGTCT , GC percentage: 60
# processing CACAGAACTGAAACTTCGCA , GC percentage: 45
# processing GTCATCGAACGGCCGGCTCG , GC percentage: 70
# processing CTCCGCACCTTTTTGCACCG , GC percentage: 60
# processing GATGCGCTGGCCTTCGGAGC , GC percentage: 70
# processing TACCCCAATCGTCACAGTTG , GC percentage: 50
# processing ACCCCTTTTGGAATAAGCTT , GC percentage: 40
# processing TGACTATATATCAAGTATTA , GC percentage: 20
# processing CAACATTAAGATTAAATGCC , GC percentage: 30
# processing CCTAAGGCTTTTAGCACGCA , GC percentage: 50
# processing CCGAGAACCATTGTCTATTG , GC percentage: 45
# processing CGGTCGGATACTGGCTTGAA , GC percentage: 55
# processing ATATTCCCCACCAACCTTCC , GC percentage: 50
# processing CCCGGGTCCTCAAGCCCAGG , GC percentage: 75
# processing CGCCCGGCTGTGCATGTTAC , GC percentage: 65
# processing TAAACATCGCTAATGCTGCG , GC percentage: 45
# processing GGGAAAACGGCGTCTTTGGC , GC percentage: 60
# processing ACAGCAGGAGTGGGCGACTA , GC percentage: 60
# processing CTTTTCGGTTCCTAGAATGG , GC percentage: 45
# processing CCACTCCTCCCAGGCACTTC , GC percentage: 65
# processing CTGTACTGAGCAGAGTCGAT , GC percentage: 50
# processing GAGAGATTATCGGTTTTGGT , GC percentage: 40
# processing TTGTGATATTGTAGGGGCAC , GC percentage: 45
# processing GCTGCACCTTGCACATGTAC , GC percentage: 55
# processing CGTTAACACCTCGTGATGCT , GC percentage: 50
# processing GGGACTTCAGAAACGCGTGG , GC percentage: 60
# processing CAAGGGGCACATCCTGTAAC , GC percentage: 55
# processing ACTCCTCCCAGCGTCTTGAT , GC percentage: 55
# processing GGGTTTATCCGAGGGGTAGT , GC percentage: 55
# processing CGCCATGGGGAGGCGGTTGT , GC percentage: 70
# processing GAAATGATCATAGCTCTAAC , GC percentage: 35
# processing CGAACACTGGATATGAGTAC , GC percentage: 45
# processing AGTATCTCTCCTTATTCCAA , GC percentage: 35
# processing TTCCGGAGCACATACATAAG , GC percentage: 45
# processing AGCAGCATCAATTTTTTTGT , GC percentage: 30
# processing CGCACAGGGCCAAATTGCCA , GC percentage: 60
# processing TAACGTGCAACGTTGCCCCC , GC percentage: 60
# processing CTCAACACTTCGGAATGATG , GC percentage: 45
# processing GCCCGCTTCTTGGCCATCGG , GC percentage: 70
# processing CGGAACATGTCCGTAGGCAG , GC percentage: 60
# processing CTATAAATAAGACGCAGTTG , GC percentage: 35
# processing CTACTTTTGCACGGGGTCCG , GC percentage: 60
# processing TAAGTTCCCCAACTGAGTCT , GC percentage: 45
# processing TTTCCCGCCTGCATCTGTTC , GC percentage: 55
# processing GACAGCACGAAAGCACCAAA , GC percentage: 50
# processing TCATGACCACAACCGAACGG , GC percentage: 55
# processing GTGTAGAGAATATTATTCTC , GC percentage: 30
# processing CGTGATGTAGCCCCTCGGCG , GC percentage: 70
# processing AAAACTCGCAAGCTTACTCC , GC percentage: 45
# processing AATATGAACGTTAGTTTCGC , GC percentage: 35
# processing GGAGCTCGACATCTGCGAGG , GC percentage: 65
# processing CTAACGGCACCATGATAGCG , GC percentage: 55
# processing GATAGTTCAGCGTTACGTAA , GC percentage: 40
# processing GACCCGTATGACCAATTCTG , GC percentage: 50
# processing AATAATCACCTAAAAGAATT , GC percentage: 20
# processing TTCTGTCCAAGCCATCAGAC , GC percentage: 50
# processing GATGTCTATTCTAGGCTCAG , GC percentage: 45
# processing TCCTGTTTTAGATTCCCCTG , GC percentage: 45
# processing CGTACTGACGGTAATTTGAG , GC percentage: 45
# processing TCGAGCGGCTTTGGGCCTTT , GC percentage: 60
# processing TAACTTACATTGGGCGATCC , GC percentage: 45
# processing TTAAACCCCGCTGAGCCGAC , GC percentage: 60
# processing CATGGCGGCAGCCATCAAAC , GC percentage: 60
# processing GAGTAAGGCTTGGGCCAGCT , GC percentage: 60
# processing CCCGATCTCTGGTATTCTTT , GC percentage: 45
# processing TTTGGGACATCCGCGGTGGT , GC percentage: 60
# processing CACGTACCGGTACTAAGGTA , GC percentage: 50
# processing GCCCGTTCTTGCGCGCTCCT , GC percentage: 70
# processing CGTGGTTCCGATGACGGAGG , GC percentage: 65
# processing GTAAGTCCTACGGGTATCCA , GC percentage: 50
# processing ATTTTGTAATTGTCTGACAT , GC percentage: 25
# processing CGTCCATTCTGCGAGCGCCC , GC percentage: 70
# processing AGACGGGAGCTCTGTAGCAC , GC percentage: 60
# processing TTATTCGCCGCACAGCCTCG , GC percentage: 60
# processing GTCAACTGGGTGCGATCGAC , GC percentage: 60
# processing TTCGGTTTACGGTACCTGTC , GC percentage: 50
# processing CCCTCTGTTTTTCGTATGCG , GC percentage: 50
# processing TGTAAACTGGGCTGCGCCAT , GC percentage: 55
# processing CACGCCTTAAGGTCGACAGC , GC percentage: 60
# processing CAAATGAACCCCTTCAACAC , GC percentage: 45
# processing GGGCTCTTTTGACGGGTTGG , GC percentage: 60
# processing ATGTAAAACCGTCCGAGAGG , GC percentage: 50
# processing TGCTTACCTGGGCCAAGTAG , GC percentage: 55
# processing TACCAGTTCGTCCCCTCGCT , GC percentage: 60
# processing CGGGGTCCAACGTTACACGT , GC percentage: 60
# processing CCACGGAACATGTCCTCATC , GC percentage: 55
# processing TTCGAGTAGATGCACCGCGG , GC percentage: 60
# processing GAAAGTTACCGGCATACATA , GC percentage: 40
# processing CAGAACCCGACTGCAGGCAA , GC percentage: 60
# processing CTATGTGACAATGCAAATCA , GC percentage: 35
# processing CTGTTACTGTTGTTACTGAG , GC percentage: 40
# processing CGTCTCTGTATCCACACGAG , GC percentage: 55
# processing GGAATTAACGAAATGTACCG , GC percentage: 40
# processing GCGGAGCAAAGCACATATGC , GC percentage: 55
# processing GAGACCTGGGGCGCGGACTT , GC percentage: 70
# processing CCCTCCTCTCAGCGTTACCC , GC percentage: 65
# processing GGATTAGCTTGCCGGCCCTC , GC percentage: 65
# processing AAACATCGACACGCACACGA , GC percentage: 50
# processing CTGGAACTTCCACTGTAATA , GC percentage: 40
# processing CGTCCTCGTTACCAACAGCA , GC percentage: 55
# processing GCGTTAAATAGTAATCTGTA , GC percentage: 30
# processing CGCCACTTGGGCCTGCAAGC , GC percentage: 70
# processing TTGGGCGGCAGACACATACT , GC percentage: 55
# processing GTTTTGGCGTTTCGGGGTTG , GC percentage: 55
# processing GAGTCCCACCAATCGTCGGG , GC percentage: 65
# processing AGAAAACAAGAGTTGTTACT , GC percentage: 30
# processing ATATAGATTGCTCCCATCCC , GC percentage: 45
# processing AGTGACGGTTACCGTGCGCG , GC percentage: 65
# processing GTGGAATGGTGCAAGAGCCC , GC percentage: 60
# processing GGCTCTTTGGCGCGATATCT , GC percentage: 55
# processing CGAAAAGCGCAGCACCCCTT , GC percentage: 60
# processing AATGGAATGCGTGACGGCCC , GC percentage: 60
# processing CCGATCTGTAGTAGATAGGG , GC percentage: 50
# processing AGAACGTAGCTCTCCTACGT , GC percentage: 50
# processing CTCTATCTGCATCAACAGAT , GC percentage: 40
# processing GTTAACCACGTCCGCCAGTT , GC percentage: 55
# processing AAGAGGCCGAAAAAAGAGGT , GC percentage: 45
# processing TAACCGCAGCTCCTGAAAAG , GC percentage: 50
# processing TACTGCCTTGCTGGATATGT , GC percentage: 45
# processing CTTGGGGCTTGAATATAGTC , GC percentage: 45
# processing TGCTAAAGTGGGTAGGGCTA , GC percentage: 50
# processing TGACCTGGGGGACGTTCTCA , GC percentage: 60
# processing CACTCTGCCACTACGAGTCG , GC percentage: 60
# processing AGTTATCAGTTAGGTATCCT , GC percentage: 35
# processing GCCTTAGAAGATTTGGTTCT , GC percentage: 40
# processing CTGCCCCCAATCTGGGTTGA , GC percentage: 60
# processing GGAAGCAAACCTATTATCCT , GC percentage: 40
# processing GAGTTTGAGTCTGGGCGTAG , GC percentage: 55
# processing CCTCACGAATTTTAATATCT , GC percentage: 30
# processing TCTCCTACACATGTATTGAT , GC percentage: 35
# processing AGTTGAACACTGGAGGACGT , GC percentage: 50
# processing CGTTAGACGCGCACAACCCC , GC percentage: 65
# processing TTCGCCCCCGCGATTTCCTG , GC percentage: 65
# processing GAATCCATATAGCTGGGTGG , GC percentage: 50
# processing CATGGGGAGGCGCTTGCATG , GC percentage: 65
# processing CCAACCCCCTCAATGTAATA , GC percentage: 45
# processing TTCATACATCCTTTGTGCTG , GC percentage: 40
# processing GTTTTCCATAATATAGCGTC , GC percentage: 35
# processing ACAAGAGCAGCAGTTTTCGG , GC percentage: 50
# processing TCTATCTTGGTAACCCACCA , GC percentage: 45
# processing TAGCACCGAGCTCGACGGGA , GC percentage: 65
# processing CCTCGCGATATCCGAGTTAA , GC percentage: 50
# processing AGGGCGATACGTTATCAATC , GC percentage: 45
# processing GACTAACAGCCGAAGCTGAA , GC percentage: 50
# processing ATAGTATCCTTACCATTCAT , GC percentage: 30
# processing AGGATACGCATGTGAAGTTC , GC percentage: 45
# processing ATCGGTAACAGCCTCGAGTC , GC percentage: 55
# processing GAACGGGCAAGGGTTCATCA , GC percentage: 55
# processing TCGTGCCTGAGGAGTCGGAG , GC percentage: 65
# processing TCAAAGTACTGCCCGGTAAG , GC percentage: 50
# processing AATCCAGGATCACAGTGCGT , GC percentage: 50
# processing TGAACGCGTCTATGAGTCCA , GC percentage: 50
# processing TATATTATCTGACAAGTCCC , GC percentage: 35
# processing ACCGAATACTCTGACTTAAG , GC percentage: 40
# processing ATGAATCTCCCTTTCCGAAC , GC percentage: 45
# processing TGTAAAGTAAGAGACGAAGG , GC percentage: 40
# processing TGTCATAGGACTGCGCGTTC , GC percentage: 55
# processing AGAAGCAGAATATATCATCG , GC percentage: 35
# processing ATGCCCGGCTGATGGTCCGT , GC percentage: 65
# processing TATCTGAGGCCGACTGCGAT , GC percentage: 55
# processing TGTCCGCCTGCTCGCCGAGG , GC percentage: 75
# processing CCCTATCGAGGTATTTTTCT , GC percentage: 40
# processing GCGGACACTGGTTCAATATC , GC percentage: 50
# processing ACGATTCTGGGCCGTGACGA , GC percentage: 60
# processing TTATGTGACGTGTGCCTAAT , GC percentage: 40
# processing AGGGCCCAAAAAGCGCTAAA , GC percentage: 50
# processing GCGCCCGCCGAAACTATTCT , GC percentage: 60
# processing GTTACGCGAAGCAAACCATT , GC percentage: 45
# processing AACAACCCTGTCGTTAAGTT , GC percentage: 40
# processing GGGTTCGAATTTTTACGGTA , GC percentage: 40
# processing GTGTTAGACATTTTGTTTTC , GC percentage: 30
# processing GGCTGTAAGCTACCTTGTAC , GC percentage: 50
# processing ATTAATAGCAAATGATAGTT , GC percentage: 20
# processing TTGGCATGCTCTTATGTAAC , GC percentage: 40
# processing TGATAGTGCCCACACCGGAT , GC percentage: 55
# processing TGTGGGAGTACGAGGGGAAT , GC percentage: 55
# processing CATAATTTTCGAATACCTGC , GC percentage: 35
# processing TCTCGTGCCGATTCATCGCC , GC percentage: 60
# processing GTGCTGATAGTTCCCTTAAA , GC percentage: 40
# processing GATCACTCAGCGTCAGGTGC , GC percentage: 60
# processing CCAGGGGAATAGTCTCCATC , GC percentage: 55
# processing ACTATGGGGTTTAGGCAGCA , GC percentage: 50
# processing TATGAGCGGAGGTACGGAAA , GC percentage: 50
# processing CTCCGGCGAGAGAGCCCCGA , GC percentage: 75
# processing GGATGTACTGATGTTACGAC , GC percentage: 45
# processing CTATTCTCCACGCCACTCTA , GC percentage: 50
# processing CGCATGGTCCTTATGATGGC , GC percentage: 55
# processing AGGCTCTACATCGGAGGTGA , GC percentage: 55
# processing CGCAGTGGGTCGCCCCGCCC , GC percentage: 85
# processing CTACTTCGGGATGCCTTTTG , GC percentage: 50
# processing TTCTACTTCCGAGCAGGCTG , GC percentage: 55
# processing AGTCTTTAAATCGCCCAGTC , GC percentage: 45
# processing AATAGTCCCCTTGGCTCCGA , GC percentage: 55
# processing TTATCCTGCAAGAATTTCGG , GC percentage: 40
# processing ATGACTCTCAAAATTACTAC , GC percentage: 30
# processing ACATTGATAAAATTATCCGT , GC percentage: 25
# processing ACGAGATCACCGAATATGTA , GC percentage: 40
# processing ATGCAAGTTCGGGATTATGA , GC percentage: 40
# processing CGAACCCGTCTACCACGTAT , GC percentage: 55
# processing TAGTTATCTTACTACGCCCG , GC percentage: 45
# processing TAGTCCGCGTGCTGGACTGG , GC percentage: 65
# processing CTTTAGCGTGATGGCATCCA , GC percentage: 50
# processing CGATGGCTGGTTGGCGTTGT , GC percentage: 60
# processing CTATAACCAAAAGACGCAAC , GC percentage: 40
# processing CGGGTATCGAATTTATTTTG , GC percentage: 35
# processing TCCTGGATACACAGCCAAGC , GC percentage: 55
# processing CAAACGAGGCATATTTAATG , GC percentage: 35
# processing GGACCACTACCGTGCTCCGT , GC percentage: 65
# processing AACGATCTTCACTTGTGGCG , GC percentage: 50
# processing TCGCTTTGGTGAGTACGGGT , GC percentage: 55
# processing AACAAGTCTTTTATACAGCC , GC percentage: 35
# processing CTTCCAGTGTCGCTCCAAAG , GC percentage: 55
# processing TAAGCGGGTCGGCTACCCTA , GC percentage: 60
# processing GCGCTTGCGAGTATTGTCTC , GC percentage: 55
# processing CGCGAGATAAGCGGCCAAAC , GC percentage: 60
# processing AACAATAAATGCGATGCAAA , GC percentage: 30
# processing TATCCAACGTGCGCCTGGGA , GC percentage: 60
# processing GTTACCGAGTCCCGAACTAG , GC percentage: 55
# processing ATATCAACTTCAAAACTCCG , GC percentage: 35
# processing AGCGTTAGCCCGGGAAGATG , GC percentage: 60
# processing AGGTATTAGAGGGCCGTTCT , GC percentage: 50
# processing ACTTAAATAGAAGGCCAAAA , GC percentage: 30
# processing GCGCAATTAGGCGTGGTTTT , GC percentage: 50
# processing CGTCCCTCTAGTAGTCGCGT , GC percentage: 60
# processing GGACGCAGGGCGCCCAACCG , GC percentage: 80
# processing TACCCAGACACTGCATAGAA , GC percentage: 45
# processing GTGACCAGACGGCGTAAGGG , GC percentage: 65
# processing GTGCAGTCTGTACGCAACTT , GC percentage: 50
# processing AAACTAGTGCCAGAGCAGGG , GC percentage: 55
# processing ATGCACCAGGAAGGTAAGCC , GC percentage: 55
# processing CCACTGCTGCAACACCCCAC , GC percentage: 65
# processing ATACTGGAGAAGAGTAAGGA , GC percentage: 40
# processing CTGGGCGCGCCAAGCAAAAA , GC percentage: 60
# processing GATAAAGCACAAATTATATT , GC percentage: 20
# processing GGGGTACAATCTCCACTTAC , GC percentage: 50
# processing TAGGGCGGCTGTAACACTTT , GC percentage: 50
# processing TCCGCATTTCATAGGACCTA , GC percentage: 45
# processing GAGTTATAGCCGGCACCCGC , GC percentage: 65
# processing GGATACAAAGGGAAAGGTTT , GC percentage: 40
# processing ATGAAGTCTGTCGAAGACGT , GC percentage: 45
# processing ACCTTGTGCTCAGACAGGTC , GC percentage: 55
# processing GCGCATTGCGACGCGAAATC , GC percentage: 60
# processing TAAAGCGGTCAACAGACGGC , GC percentage: 55
# processing TACCGCGAATAGACTTGGCC , GC percentage: 55
# processing TACGCAATCTAAACAGATTA , GC percentage: 30
# processing CAACTTATTCGAGTTGCGTA , GC percentage: 40
# processing GTGAAGCCCTGCTTATGGGA , GC percentage: 55
# processing GTCAAGCGTCCGAAGAAGGT , GC percentage: 55
# processing GGCCATGGCTTTCCCCTACA , GC percentage: 60
# processing CTCTTCCACTACTCCATGGT , GC percentage: 50
# processing TGCGGGAATCTCCCAAGTCC , GC percentage: 60
# processing AAACCTGCGTGGCAGTGGAT , GC percentage: 55
# processing CAGTACTCATTAGACGCGCG , GC percentage: 55
# processing AGCCGGGCAAGAAACTCTAA , GC percentage: 50
# processing ATCAGGACCGTCGCAAGCAA , GC percentage: 55
# processing ATTGATCCAAGCGAAACGTT , GC percentage: 40
# processing CTCGACACTGGGGCTATGAA , GC percentage: 55
# processing CAACCATGTTCTAAGGGGCA , GC percentage: 50
# processing CCCCAGCGGTGTCACTTTTG , GC percentage: 60
# processing GATTAGTCGTGGAGTGGGAG , GC percentage: 55
# processing CCCTGAGCGTTCGGCCGATA , GC percentage: 65
# processing TACTACGCCCGGACAAAGTC , GC percentage: 55
# processing GGACAACCCCGCAATACTTA , GC percentage: 50
# processing GACTTTATTGATAAGCAATG , GC percentage: 30
# processing TGCGGAGACAACTTTGATCG , GC percentage: 50
# processing GGGTCCCACGCTACCGGTAA , GC percentage: 65
# processing CGCGGTCCGTACCGTGAGGC , GC percentage: 75
# processing AGCCTCAGTTACGCCTTCGG , GC percentage: 60
# processing TTCGCACAGTAGCTGCTGCC , GC percentage: 60
# processing CCAGGATGCGCATATTGGCG , GC percentage: 60
# processing CTGTGCAAATGCCCACGCGG , GC percentage: 65
# processing CTGGATGACATTCGATATGT , GC percentage: 40
# processing GCAGCTTATGATTCGTTGCT , GC percentage: 45
# processing CGGATAAAGCTCCCTGGAAT , GC percentage: 50
# processing CTAAGTCAGTTGTGAACAGT , GC percentage: 40
# processing GGTCAGTAAGCATGAGTGTG , GC percentage: 50
# processing TGGCAACGCTAGGCGGCGTG , GC percentage: 70
# processing ACTCTAAAATAGACTTGATA , GC percentage: 25
# processing CGCCACGCCTGCGAGCACAG , GC percentage: 75
# processing TGCATCGCGAAAGGCGAGGG , GC percentage: 65
# processing GTCATCTCGTCAGTTGGAAC , GC percentage: 50
# processing CGACTATTGAGTTTGCCCGG , GC percentage: 55
# processing CGCCTGGCAATTCTATATCT , GC percentage: 45
# processing TGGGGGCCGGAGACAGTCCT , GC percentage: 70
# processing GTTTACCCGTGAGAATATGA , GC percentage: 40
# processing CAGTGACTAAAAATGCTGAC , GC percentage: 40
# processing ACACTAACTGTGTATATGTG , GC percentage: 35
# processing AAAGTGAGCGGTCCGTTGAT , GC percentage: 50
# processing TTTCCGGACTCGGGACGGCA , GC percentage: 65
# processing TTGATTGATGAGCTGTGGGA , GC percentage: 45
# processing GCTATTGCGCCTGTAAAGAG , GC percentage: 50
# processing CGTGCAACTTAGTATAATAC , GC percentage: 35
# processing TGGCCCTTCCTGTACTTCCA , GC percentage: 55
# processing TCCGCTAACGGTCCGCGGAG , GC percentage: 70
# processing AGTGAACTAAACCCACTGTC , GC percentage: 45
# processing GATAAGCTACCTATGAGTTT , GC percentage: 35
# processing CATAAATTGAGTTAGTCCGA , GC percentage: 35
# processing TCACTGTCCTAGACGGTTAA , GC percentage: 45
# processing CAAGAAAGCTTACTACGACG , GC percentage: 45
# processing GTCTGCCTTTAGCTGGGGTC , GC percentage: 60
# processing AATGGACTCCGACATAATCT , GC percentage: 40
# processing ATGGCGTCGTGTATCAACAG , GC percentage: 50
# processing GAAAAGCCTGCAAATCCCGC , GC percentage: 55
# processing CCGGCGATCGCGAGCTCAGA , GC percentage: 70
# processing TGGCTCCCTTTCTCGACTCT , GC percentage: 55
# processing AAAACCCCAAGTTGCAAAGT , GC percentage: 40
# processing CTTCAAGCCTAGCACCCCAG , GC percentage: 60
# processing CTCTGTAGGGCGTATAACGA , GC percentage: 50
# processing TTCACGAGCCCCGACGTGCC , GC percentage: 70
# processing CGGTTTCAGGCTCGCCGTGG , GC percentage: 70
# processing GACCGGCCATACCTGATGGT , GC percentage: 60
# processing AGCGACCTAACCCCAGAGCG , GC percentage: 65
# processing TCGGATATATTGTACTCCAC , GC percentage: 40
# processing GACCCTAGATTCTCGACTCA , GC percentage: 50
# processing GACTACCCACTTTATGCCAA , GC percentage: 45
# processing CGCCGCATGTCAATTTTGAT , GC percentage: 45
# processing CTTTATCATTTCTGCACGGG , GC percentage: 45
# processing AAAGGTAGATGCGTCACGGC , GC percentage: 55
# processing AAAGCTACCGATCCGAGCTC , GC percentage: 55
# processing GTGCCCGTCAGGTCTTATTC , GC percentage: 55
# processing CTCGACAGCACTCATCCGCC , GC percentage: 65
# processing GCAATTTAGGAGTTGCTGTT , GC percentage: 40
# processing GATCAAACTCCCGTTGTCCT , GC percentage: 50
# processing ACGCACGTTCGTTAGGTCCA , GC percentage: 55
# processing AACCCCCTATACGGTCGGCG , GC percentage: 65
# processing GTCAATAGTAAGCACACATG , GC percentage: 40
# processing ATGAGATGCATGCATATATC , GC percentage: 35
# processing AGGTAAGCTCTCTATTGATA , GC percentage: 35
# processing AAGAATATCCTCAGGTGTTG , GC percentage: 40
# processing CGAGTATCGGGCATGGCATC , GC percentage: 60
# processing CGAATTAGATCACAATCTCG , GC percentage: 40
# processing CCATACAGTTGGAAGACGGG , GC percentage: 55
# processing TTGACTGTAGGTTCGAAAGT , GC percentage: 40
# processing GGCGAATTCGGGCGTTGTGT , GC percentage: 60
# processing AGCAATCTATCGGCAGTTGC , GC percentage: 50
# processing CCCACCGTTGGATCGATAAC , GC percentage: 55
# processing AGATACTGACACATGTCAGT , GC percentage: 40
# processing TAGTCGCTATCCCCCCGCAT , GC percentage: 60
# processing GAATAGGCCGTATTGGAGGC , GC percentage: 55
# processing TGACATGGGGCAGAACGAGA , GC percentage: 55
# processing TCGCATAGGTGGATCACTGC , GC percentage: 55
# processing CGACGGTACCGGCCGGTCCG , GC percentage: 80
# processing CCTGCTATATACTCTATTAA , GC percentage: 30
# processing AGTTAACCACATTACCGATC , GC percentage: 40
# processing AGAGTGCAACCTCGATTTTC , GC percentage: 45
# processing GTTAACTTCATGGGGCCCTG , GC percentage: 55
# processing TGCTCGGAAGTCGATAGGAG , GC percentage: 55
# processing GCGGGACCTGGGGTCTAAGA , GC percentage: 65
# processing TATCGCTTGTCCCCTCAGCG , GC percentage: 60
# processing TATCCCAGGACGCAAGTATC , GC percentage: 50
# processing TTCGGGGCCCTGTCTGCGCC , GC percentage: 75
# processing ATAGTTATAGCAATTTTTCA , GC percentage: 20
# processing CTGAGCCTATAGGTTCAACC , GC percentage: 50
# processing ACAACCCTTTTAGTTCTGTA , GC percentage: 35
# processing GGCTATGCTCCGTATTTATA , GC percentage: 40
# processing GATGGGATGCTGGTCAATGA , GC percentage: 50
# processing AAGTCACTCACTGAATGCCG , GC percentage: 50
# processing CTTTAGTTATTCATGAGTTG , GC percentage: 30
# processing GCCCTATGTTACCATGACTT , GC percentage: 45
# processing ACGCGTAGCATACCTCGGTG , GC percentage: 60
# processing ATCTTGTGAACGCAGGAGGC , GC percentage: 55
# processing TCTCAGGGGCATCACGACAA , GC percentage: 55
# processing ACCTACATGGAAAAGCGTAC , GC percentage: 45
# processing CGTAACGCGCAGGAATAGGC , GC percentage: 60
# processing AAGGGGACCGCCGTTATCAA , GC percentage: 55
# processing TGTTAGTTTAAGGACATATA , GC percentage: 25
# processing ACTTACCTCTCCAGCTCCAG , GC percentage: 55
# processing ACGTGTTCCGAAGAGCCCGC , GC percentage: 65
# processing ATCTTCAGATAGACCATACT , GC percentage: 35
# processing TGAGGTCTACATGTAGCGGA , GC percentage: 50
# processing GGCCCGACAGGAGAGCGTAT , GC percentage: 65
# processing CCTCATGGACGCTCAGTGCA , GC percentage: 60
# processing TAGGGCGTTTTCGCCTAGGA , GC percentage: 55
# processing GTACCTTTTAGCGGTTCAGT , GC percentage: 45
# processing TATGCCATGCGCTATCAGTA , GC percentage: 45
# processing ACAAATAGTTGCAAATTCAG , GC percentage: 30
# processing ACAACCGAAATGAACGGGCA , GC percentage: 50
# processing GTATGATAGGTGTAAAAGAA , GC percentage: 30
# processing AGTACAATTTGCTCAACAAA , GC percentage: 30
# processing TCACGCGACGTAGCAGGTGC , GC percentage: 65
# processing TTTCCGTCTAGTTGCCGCGA , GC percentage: 55
# processing TTTCGCCTTACTTCACCGGA , GC percentage: 50
# processing AACGGACTCACCCACTAACG , GC percentage: 55
# processing TTTGTCTATATAGGCAGGAG , GC percentage: 40
# processing CTCGTCGAGAAATCAAGGCT , GC percentage: 50
# processing TATCCTATACGCTGCTATTG , GC percentage: 40
# processing TAAGACGCTCCGCCGACAGA , GC percentage: 60
# processing TCTGTCACATGCTGATAATA , GC percentage: 35
# processing CGCCCTCTCCGAGGGATAGG , GC percentage: 70
# processing TGCAGACGCGGAAGCATTGT , GC percentage: 55
# processing GGCAATGGAGAGGGCATCTG , GC percentage: 60
# processing CTGGTTCTGTTCTAGGGGCT , GC percentage: 55
# processing TCAACCCAGTGGATGCACAG , GC percentage: 55
# processing GCTGAAAATAATGACGATGC , GC percentage: 40
# processing ATACCATAAAGCTTGTGACC , GC percentage: 40
# processing ATAAACATGGGTATTATCGG , GC percentage: 35
# processing GAAGTTCTGTGCCATTATGG , GC percentage: 45
# processing GAATCATCTTTTTCCTTATG , GC percentage: 30
# processing AATCTGCTCAATCTAATATT , GC percentage: 25
# processing GCTCCCGAATTAACTTTTAC , GC percentage: 40
# processing AAGCTTGTCACTAACCGCTT , GC percentage: 45
# processing ACGAGACCCGATACAACTTC , GC percentage: 50
# processing TCCTCGGAACTTAAGTGGGT , GC percentage: 50
# processing CATTTCGGATCGACCGCAGT , GC percentage: 55
# processing CGCCCGGATGTTAAGCAGAG , GC percentage: 60
# processing AGTCGATTTGTCATGGTTCC , GC percentage: 45
# processing GCTATTTAAGCTGCGTCTTT , GC percentage: 40
# processing CCTCCCCACTAATCTCCTTT , GC percentage: 50
# processing TCCGCCTCGTTTGGTTCCTT , GC percentage: 55
# processing CCATGCTTTCAAAACAGGGG , GC percentage: 50
# processing TGACCACCGACTAATAGTTC , GC percentage: 45
# processing GATGATATCCCTGGTGTGCA , GC percentage: 50
# processing CCAAACTACGTCTCTTTCAG , GC percentage: 45
# processing CCCTCTCCTAGAGGACCGAC , GC percentage: 65
# processing TATTGAAAATCGGACCTTAC , GC percentage: 35
# processing ACGGAACCACACCCCAGTAC , GC percentage: 60
# processing AGCGTCTTCACTGCACTCCC , GC percentage: 60
# processing TGAGTGTGAGGTTGTCCTCC , GC percentage: 55
# processing AGTACCTATTGAGACTCGCG , GC percentage: 50
# processing TAGGCTTAGGGCGAACCGCA , GC percentage: 60
# processing GTCAAAAACATCACGTGAAT , GC percentage: 35
# processing AGACCATTGGCACAGTAGAC , GC percentage: 50
# processing CACGGTCTTTGAGAGTTATT , GC percentage: 40
# processing TCAGGGAAAGCCTTATCTTT , GC percentage: 40
# processing ATAGGTACGATTCAGTCGCG , GC percentage: 50
# processing TCCGCGTTGGTCGAATGGCT , GC percentage: 60
# processing ATGCATCAAAACTGAATAAG , GC percentage: 30
# processing GTCAGGTTGGGCCGCTTGTG , GC percentage: 65
# processing AGTGCCGAAAGCGAAGGGAG , GC percentage: 60
# processing TAGGGGAAATGGGGCGATGT , GC percentage: 55
# processing GCCGCTCACTAACACTATAC , GC percentage: 50
# processing GTGGCAATTCTTCATGATCC , GC percentage: 45
# processing TCCGACCTTCAGGTCATGAC , GC percentage: 55
# processing CCAGCGACCTGATCTAATCT , GC percentage: 50
# processing TTAGCACAAGCTTACGGTTC , GC percentage: 45
# processing CATAGCCTCCCAAGGACATA , GC percentage: 50
# processing GCGGTACGAGACTGCCTACG , GC percentage: 65
# processing GCATCCTTGTACTTAAGATT , GC percentage: 35
# processing TGTAAGTTTGGAATTGGCAA , GC percentage: 35
# processing CGGTGCCCTGAATGTCGAGG , GC percentage: 65
# processing TAATGAACAGCAAATCGTTA , GC percentage: 30
# processing GACATGAGTTACCGTCGACG , GC percentage: 55
# processing GGGGACGTTATCTAGTACGA , GC percentage: 50
# processing CGGATAGTTCGAGACGTCTG , GC percentage: 55
# processing CATTCAGTGTGGTTTCAACC , GC percentage: 45
# processing GGTGATAGCTACGAGCGCGC , GC percentage: 65
# processing GTTCCTAACGTGGTTCGAGA , GC percentage: 50
# processing GGTGTGCAGCCTGGATGGGT , GC percentage: 65
# processing CTTGCTACCCGCTAAGTCGG , GC percentage: 60
# processing ACAAGGCGATAAAACAACCT , GC percentage: 40
# processing GCAGCCGGATTTGGGGACGA , GC percentage: 65
# processing GTAAGATCTTTGTAGTCACG , GC percentage: 40
# processing AGCTCCGCCCTCCCCTTGGA , GC percentage: 70
# processing CCACTGACAGAAATCGACGA , GC percentage: 50
# processing ATCGCGTTGTAATCGTCGGG , GC percentage: 55
# processing GGTTTGGCATACTGACAACG , GC percentage: 50
# processing GCATCAAAGCCCGGGCAGTA , GC percentage: 60
# processing CTCGTTGTTCGTAGACTAAT , GC percentage: 40
# processing CCTAAGCATCGGCTGAGACC , GC percentage: 60
# processing CTTAACTGGCTATTTGCTCT , GC percentage: 40
# processing GCAGCCAAAACGAAGTAATA , GC percentage: 40
# processing GTTCTTGTGTATTCTCTGGA , GC percentage: 40
# processing TCGTTATGGGGGCGAGTAGG , GC percentage: 60
# processing AAAGTAATACATGGGGTCTT , GC percentage: 35
# processing GATTAAATGTGTCCCTCTAC , GC percentage: 40
# processing AAAAAGGAGGGATCAACGGC , GC percentage: 50
# processing GCACGCTACGCGGCTTCTGT , GC percentage: 65
# processing CTAAGGTTCCCGTATAATTC , GC percentage: 40
# processing CCATTGGGTCATATCCACAA , GC percentage: 45
# processing CTTCTGATCGTTATAGTGTC , GC percentage: 40
# processing CAAATCATGTGATCGGTGAA , GC percentage: 40
# processing ATCAAGCGAGCAGTGCCCTC , GC percentage: 60
# processing AGAACGAGTGAATTTTGCCT , GC percentage: 40
# processing CCGCAGGGGCTTAAGATGTT , GC percentage: 55
# processing CAATCGCTCTTGAAGTCCAG , GC percentage: 50
# processing CCGAACCAAGTCGGGACATG , GC percentage: 60
# processing ATGTCTAGGATTAGCAAATA , GC percentage: 30
# processing ACCGACTAGTTAGACGCCTA , GC percentage: 50
# processing GAGGTACCCCATCCAGGACT , GC percentage: 60
# processing CAGCCGATCACAACTAAACC , GC percentage: 50
# processing GTTCACTCGAAGCAATTCTC , GC percentage: 45
# processing AGTGCCAACTAAGTAAAAGG , GC percentage: 40
# processing CCTAGATGGCAATAGCTTTT , GC percentage: 40
# processing CTCTTCTGGAGTACCACCTT , GC percentage: 50
# processing ATAGTGTAACTTGCTAGCGC , GC percentage: 45
# processing CCTCAGCTAAGGTTTTCGTA , GC percentage: 45
# processing GGATTCGGTGTGAGCTGTGT , GC percentage: 55
# processing GATTGGGCCTCCAATCCTAC , GC percentage: 55
# processing GACGGTTCGCTTGTTCTCTT , GC percentage: 50
# processing AGTCGGAGCACGATCATGGG , GC percentage: 60
# processing TCGCAGGAATGGTTATCGTG , GC percentage: 50
# processing CTGTTCCTGGCGTGAATACC , GC percentage: 55
# processing CCAAGTTACTGCACGGGTAT , GC percentage: 50
# processing AAATCATACGACCGTCACAG , GC percentage: 45
# processing TCTATATTTGCCAGCTCAGT , GC percentage: 40
# processing CTGTTTCGAAGAATAATTCT , GC percentage: 30
# processing GCTGTCTTTGACATATAATG , GC percentage: 35
# processing CTTTGGTACGGGAATGCCCC , GC percentage: 60
# processing GCGTAGGCGTCCTACATACC , GC percentage: 60
# processing CGTGACAAAGAAGCCACGCT , GC percentage: 55
# processing GTGATCTCTAAACTGTAGTC , GC percentage: 40
# processing CTTTAGGATGGCTATAGAAA , GC percentage: 35
# processing AAGCATATGACAATGAGACT , GC percentage: 35
# processing ATCCCCTGCGGCCTGTCCCA , GC percentage: 70
# processing TTCAACGGCCCGCGTATGCT , GC percentage: 60
# processing GTGTCCACGTATTGCCATGA , GC percentage: 50
# processing CTTAACCTCCCTCCGTGACG , GC percentage: 60
# processing CCTCAGTCACCCCGTTGGCG , GC percentage: 70
# processing GTGCAATGGACGCAAACGGT , GC percentage: 55
# processing GTACGAGTTCTGATAAAAAG , GC percentage: 35
# processing AATTGAGAATGAGGAACGAA , GC percentage: 35
# processing GCGAATGCATACACGAACGG , GC percentage: 55
# processing CTGCTTTGGGGATGTTGAAA , GC percentage: 45
# processing CTTTCGACACTTCAAAATGC , GC percentage: 40
# processing TTGTATCCACAATTGGGAGA , GC percentage: 40
# processing AGACGGTTCGCTTTTATTTA , GC percentage: 35
# processing TCGAAGAGTACAGGGGACAT , GC percentage: 50
# processing GCAGTGTTGAACATAGAAGT , GC percentage: 40
# processing GGCGAATGTGCGATCAGCGT , GC percentage: 60
# processing TTGGATACATACTTATTAAC , GC percentage: 25
# processing AACCGCGGATTGGAAATTGA , GC percentage: 45
# processing CCATGGTGGTCATACGAGCT , GC percentage: 55
# processing TCTGCACGAAGGCTAATCCG , GC percentage: 55
# processing CGGGGTACTTCCTGCAGGTT , GC percentage: 60
# processing GTGTGGCATTTCCTGGTTAT , GC percentage: 45
# processing AGCCGAACGGTTCTCACACT , GC percentage: 55
# processing CAACGCTGAGTTAGCTGCGG , GC percentage: 60
# processing GGCTTTAAGCGTGACCGACG , GC percentage: 60
# processing GGTACCGTTGGCCTGTCGCA , GC percentage: 65
# processing GACCACCGAAGGACCTAGGA , GC percentage: 60
# processing CCGCAATAATTAGCCCGCAC , GC percentage: 55
# processing ACATCACTAATGAGAACTTG , GC percentage: 35
# processing AAATGTCAGTATTTGATCCG , GC percentage: 35
# processing ATCTTGGGTTACAATGGGCA , GC percentage: 45
# processing AATATTGATCCCAAAGTGAG , GC percentage: 35
# processing TGCGACGCATAGGATGATGT , GC percentage: 50
# processing TCTTGACAGACTTGAGTAGA , GC percentage: 40
# processing TTGAAGTAAGCTTAAGCAAA , GC percentage: 30
# processing CACGTTAATGTGTACCGTTT , GC percentage: 40
# processing GAATCCCCGTTGTCCGTAGC , GC percentage: 60
# processing TATTGCGTACCTGACCCGAA , GC percentage: 50
# processing GCCGGTACTATCCTCTGATA , GC percentage: 50
# processing TCTTAGGGCTTGTTTCGCAG , GC percentage: 50
# processing TTCGCACCGGGGAAGGGCCG , GC percentage: 75
# processing TTTGCATTATACTCACCTAC , GC percentage: 35
# processing TCTGTGGGACTCTCAGATTG , GC percentage: 50
# processing TCGCAATTGAGGTTTTGACA , GC percentage: 40
# processing AGAGCACGTAATTAGTACAT , GC percentage: 35
# processing TGTGTCAACCTCGGCGCCAT , GC percentage: 60
# processing AAACGGCAACGTATTTTTTT , GC percentage: 30
# processing GCCGGGCCCTACTGTACTCA , GC percentage: 65
# processing TACGACTGCCAGAGAATCCC , GC percentage: 55
# processing GGAGGTTTCATGAGATCCGG , GC percentage: 55
# processing GGATCACGAAGCCCTGACGT , GC percentage: 60
# processing TGGCGAACCACTCGTAGTCG , GC percentage: 60
# processing AGATTGTGATCGTAGCCGTC , GC percentage: 50
# processing GAGGCGGTACAATATTGCCT , GC percentage: 50
# processing TACAGTAGGACTACCTATGA , GC percentage: 40
# processing ATGTATTGCCACAGAATATA , GC percentage: 30
# processing CTCCAATACAATGCGCCTCC , GC percentage: 55
# processing CGCTGTCTACGACAGGCTGT , GC percentage: 60
# processing ATACCAGGTTATGGGTGAAA , GC percentage: 40
# processing TAGTCTCAAAATAGGATGTG , GC percentage: 35
# processing AGGCTTTAGTCGCTAGTAAT , GC percentage: 40
# processing GCAATAAGATACGGCATGTG , GC percentage: 45
# processing CAGGACAATAGAAACAATCC , GC percentage: 40
# processing CCATAGAGCGGCAATTACTC , GC percentage: 50
# processing CATACCCTGGCCTAGCCTTG , GC percentage: 60
# processing ACCTACTTCTCGTCGAAGAA , GC percentage: 45
# processing GCTAAAGTCAAAACGTAGGT , GC percentage: 40
# processing GGATTGGTCCTCGACAGCGA , GC percentage: 60
# processing ACTGGTGCCAGTATTGTCCG , GC percentage: 55
# processing CGGACGATCTGAAACGCTAG , GC percentage: 55
# processing CGAGTCTGTCTTCGGCTGAT , GC percentage: 55
# processing CAACGCGGCGATTTACGGGG , GC percentage: 65
# processing ATCTACTGGTTACGCGCTAA , GC percentage: 45
# processing GATCCCGCATTCACAAGGAT , GC percentage: 50
# processing GTAATTCATAGCCTCGTAAC , GC percentage: 40
# processing ATCGCTAGTGGAGTTGCGTT , GC percentage: 50
# processing TCCTCAACAAGCAGCAAAAC , GC percentage: 45
# processing TTTTACAAGGTTGACGGTCG , GC percentage: 45
# processing GGACCAACGCTGGCACCAGA , GC percentage: 65
# processing CCGGGTTCAACGGGTGACTC , GC percentage: 65
# processing GATGGAGTTCTAGTTCGCTG , GC percentage: 50
# processing CTGGCCGCCAAAATGCTCTC , GC percentage: 60
# processing TAAGTCCGGACGTCAGGCGT , GC percentage: 60
# processing TCCCCTCTCATCCGCTCGAG , GC percentage: 65
# processing TCCACATATTGTCTACGCCA , GC percentage: 45
# processing CGAGTAGACTTCATGGGGGG , GC percentage: 60
# processing AGCTAATATACGTCCCGAAA , GC percentage: 40
# processing ATAATAGAGACACCGGCGAT , GC percentage: 45
# processing TACTATGGTACCGCGTGTAG , GC percentage: 50
# processing GACACCTCTCTACGTATTCC , GC percentage: 50
# processing CCCCTGGCCGAGCCCTGGGT , GC percentage: 80
# processing TATTGAATGAAAGAAGGCAA , GC percentage: 30
# processing TTCCCGCTGCCATCGGAGAA , GC percentage: 60
# processing TAGGGCTTCCCAGCTATTGG , GC percentage: 55
# processing TTAGAGACGTATGGACCACC , GC percentage: 50
# processing CCTTGTGTTATCGCATGAAT , GC percentage: 40
# processing GCCGATGTCGGCTTACGGCT , GC percentage: 65
# processing GCTGGAATACTACCTGGATT , GC percentage: 45
# processing TATGATGGCCTCGTCTGCTC , GC percentage: 55
# processing GATTAGGAATGATCTACAGC , GC percentage: 40
# processing ACGAAAATGCCCCCCACGCT , GC percentage: 60
# processing AGTCTGTGGTCAGGCAAGGA , GC percentage: 55
# processing TGGACCTAATGTTCAAAATA , GC percentage: 30
# processing TGCCGTGCATGTGATGCGGT , GC percentage: 60
# processing CAGCAATTTCGCCATCATTA , GC percentage: 40
# processing CCTCGCTTTTGAATTCCAGA , GC percentage: 45
# processing GATTTAAGTCATTCAGATTC , GC percentage: 30
# processing TCAGTGCGCGTGTACTGCCG , GC percentage: 65
# processing ACAAGACAGGTCGCTCGTCC , GC percentage: 60
# processing CTCTTCATGCTGATGAGGAC , GC percentage: 50
# processing TGATTTTGACGGTCTTAATG , GC percentage: 35
# processing CCAACAGAGGTCAATGGATG , GC percentage: 50
# processing TAGGGATTACTGGCAACCCA , GC percentage: 50
# processing TAACACGATCCGAACCCTCG , GC percentage: 55
# processing GACTAAAATAAATTACTCGT , GC percentage: 25
# processing TAAATCGCACTGCAGGATGT , GC percentage: 45
# processing ATCAAACTACTCCTGACCTC , GC percentage: 45
# processing ATCCAATATTCAACCAAGAC , GC percentage: 35
# processing TTTGCCAGTGCCTTTTGTGT , GC percentage: 45
# processing TTGATGTAGGTGTTACAATC , GC percentage: 35
# processing GTCTGCCGATGTGATTGGTA , GC percentage: 50
# processing AAGGTGGACAGAGTCTGGTA , GC percentage: 50
# processing CCCTGAATGTTCATTGGAGG , GC percentage: 50
# processing TATGTCCAGTTGACGTGCAA , GC percentage: 45
# processing CTGCGGTGTACTCTACATAA , GC percentage: 45
# processing GATGGTTACAAATGAACAAG , GC percentage: 35
# processing CGATTCCCCGTATCAGAGCC , GC percentage: 60
# processing CCAAATGGGGTCGCGGCAAG , GC percentage: 65
# processing ATGATTAAGGGGCTGAGCGC , GC percentage: 55
# processing TCCACCAGCCGTTCTCCACG , GC percentage: 65
# processing AACAGGTGTCGCGTTATAAT , GC percentage: 40
# processing CTGTCTATTGCTGGACGCCC , GC percentage: 60
# processing GTGCAATACGGTCCACCATT , GC percentage: 50
# processing TGTGATTCCGCGATTAGAAC , GC percentage: 45
# processing CGAATGCAAGGATGACAGTG , GC percentage: 50
# processing GCGTCTGACTTGAATGGAAC , GC percentage: 50
# processing CACATCTGGCGACCCACTTA , GC percentage: 55
# processing AACCGTTGAATTAGGTGTTA , GC percentage: 35
# processing CACTTAGGTGTGGTGACAGG , GC percentage: 55
# processing TAATCATTGAGTGCGTATTT , GC percentage: 30
# processing TACCCCAAAGCTACAGCGAA , GC percentage: 50
# processing TCTTATACATCCCTGCCCAG , GC percentage: 50
# processing TCGCCCACAAGATGACGAAC , GC percentage: 55
# processing TTGATCCAAGCTGTGCTTCG , GC percentage: 50
# processing ACGAGGCTAAGTATTGTGAC , GC percentage: 45
# processing AGGAGCAGCGAAGTCGCCCA , GC percentage: 65
# processing AGCCTTGGGCTTTTGCAAAA , GC percentage: 45
# processing AAATTACTTGTGTGAAATCA , GC percentage: 25
# processing CCATGATCAGTGTTTGCTCC , GC percentage: 50
# processing GCCCCATCCATACGATTAGC , GC percentage: 55
# processing CGATCTAGAGTTGAGTTCGC , GC percentage: 50
# processing TCACGATTGCTCGCGGAGAC , GC percentage: 60
# processing CGACCCAACCATGCTAGCGC , GC percentage: 65
# processing GTAACGTCGGCGGTGTAGCT , GC percentage: 60
# processing TCCCCAAGTTTACTAAAGCG , GC percentage: 45
# processing GTCACTTTTAGCCAAGAGTT , GC percentage: 40
# processing CTGATGGATTAGTGCCCTTC , GC percentage: 50
# processing ATCCCGTCGAGATTTTGCAG , GC percentage: 50
# processing TTAACATATCTCATAACGCT , GC percentage: 30
# processing GAGTAACCCTGTGAGGCGCA , GC percentage: 60
# processing AAGTCCTATGGGTGCCACGC , GC percentage: 60
# processing AGCCATGTATCGCTGTCTAC , GC percentage: 50
# processing CGTTCGTGGTTCAGTCAGCG , GC percentage: 60
# processing GCGCCAGAGAAGACCAGTTT , GC percentage: 55
# processing TTTTCGCTACTTTTACTCTG , GC percentage: 35
# processing CGCCCCTAATCCTCCGATTT , GC percentage: 55
# processing ACATTTGATCGTACTATGCG , GC percentage: 40
# processing GGTGTGGGCGAGTTCAACTG , GC percentage: 60
# processing CCTAATGGTCTATGACCACT , GC percentage: 45
# processing AGGTTGGTGTCGTTCGACTA , GC percentage: 50
# processing CCACTCCGCGTATAGAAGCC , GC percentage: 60
# processing TATGCGGGCTGCGAGGGGGG , GC percentage: 75
# processing ACTCATCGGTGTTCATTCCC , GC percentage: 50
# processing CACGTAAACATTGTATCTCG , GC percentage: 40
# processing GTTGCCGAAACGTACTGCCT , GC percentage: 55
# processing TTTTCGAGATCGAGACTAGT , GC percentage: 40
# processing TGCCTATCAATGGTTGCCGT , GC percentage: 50
# processing CAGCCCCACAGATCTTAGAC , GC percentage: 55
# processing GCTCTTATGCGATTCAGTTT , GC percentage: 40
# processing GCTCCCCGGAGGGTCGACTC , GC percentage: 75
# processing TTAGCTTATATTAGTGCGTA , GC percentage: 30
# processing AAGCGACCAAAATCACGTCA , GC percentage: 45
# processing TGAGTGATTACGGTGGGCTC , GC percentage: 55
# processing GAACGAGCGGGCGACCGGCA , GC percentage: 75
# processing TATCTGAAAATTCCTGAATG , GC percentage: 30
# processing CCCGGCCACAAATCTCGTGA , GC percentage: 60
# processing CTCACAAGAGGCGGAACCGG , GC percentage: 65
# processing GATTCCCACAGACTTCTACC , GC percentage: 50
# processing GGAAGATTAAGATCTAAGGC , GC percentage: 40
# processing ACCTCTTGAGGCCGCTGGAC , GC percentage: 65
# processing ACTGCGAAAGCAAACAGTCT , GC percentage: 45
# processing GCATTATGGCCCAGCAGGTA , GC percentage: 55
# processing ACAAGTTCACAACCAATCCT , GC percentage: 40
# processing CTGACGGGAACGGTGTACCG , GC percentage: 65
# processing GTCTGGCTGCCGTTACAGCC , GC percentage: 65
# processing GGAGAAAGGTTTCTTGTTCT , GC percentage: 40
# processing TGGTTCAGAGCAGGTCGCCT , GC percentage: 60
# processing TGAGTCTTATTGTCGTATAT , GC percentage: 30
# processing GGGGCTGATTCTCATGGCAA , GC percentage: 55
# processing GTTTAAGGAGTGGAAGCCAA , GC percentage: 45
# processing ATGTGCTTTGTAACATCGCC , GC percentage: 45
# processing GGCTTTCAATCATCTAGGGG , GC percentage: 50
# processing CTAGACTTGAGCGCGGTTGT , GC percentage: 55
# processing TTGTGTGAATCACGCCTTAT , GC percentage: 40
# processing GTCATTTTTCGGATTAGACG , GC percentage: 40
# processing CCAGATTTTAGGTACGAAAT , GC percentage: 35
# processing GTGAAGGTCTCAAGTGATCC , GC percentage: 50
# processing ATAACCTAGCTAGGAGCTGG , GC percentage: 50
# processing ACGGAGGGGCGAAGCCTCCG , GC percentage: 75
# processing TCAGCTCGACTAATTAGTCC , GC percentage: 45
# processing TCGCGCTCGTGGCCGAATAT , GC percentage: 60
# processing TGAGATATCTTTTATGTCAG , GC percentage: 30
# processing ATGAAACCAGGATCGGTCTT , GC percentage: 45
# processing ACGTGAACTAATCTGAGATG , GC percentage: 40
# processing TTATGGGAGTTAGTCCCTAC , GC percentage: 45
# processing TATCCAGAGTCATGCATTCA , GC percentage: 40
# processing TAATTGTCCGTGTTTTGCAG , GC percentage: 40
# processing AATTCCGATGAGATCTTTGA , GC percentage: 35
# processing TGGCAATAATCTCAACCGCC , GC percentage: 50
# processing CCTCGGGGTTTTGGTCTCCC , GC percentage: 65
# processing GGCGACATGCGCTATGGGAG , GC percentage: 65
# processing CATTATGGATCGTTAGATGA , GC percentage: 35
# processing TCTCGTCCGTACAAATAGGT , GC percentage: 45
# processing CAATGATAGATCGCACGTGG , GC percentage: 50
# processing TAGGGTATCGTCTAGTGTAG , GC percentage: 45
# processing TCCTCATCAGAAGGCACTAT , GC percentage: 45
# processing GGGTCCGATATTTATTAGCG , GC percentage: 45
# processing TCAAGCGTGGAATGACACTC , GC percentage: 50
# processing GTACTAACGCGCGTGGCATA , GC percentage: 55
# processing GACGTGCACACTTGGCTCCA , GC percentage: 60
# processing AACAATGTTTCTGTAGGTTG , GC percentage: 35
# processing AGCCACGCCCTCTCTGGCCG , GC percentage: 75
# processing AGACGAGTGTAGGCCTTTCG , GC percentage: 55
# processing GTTGCCAGTATAGCAGCATG , GC percentage: 50
# processing CTACGAAGAAAAGGTTGGGC , GC percentage: 50
# processing TTGTCGAAGGCATTCCTCGC , GC percentage: 55
# processing GTCGTGTATGCGGACCGCGG , GC percentage: 70
# processing TTCCTTTCCTGGCACAGTTT , GC percentage: 45
# processing ATGCCTGCTCGTACACGGCG , GC percentage: 65
# processing AGGCCGGAGGCCAGGCCGTG , GC percentage: 80
# processing ATTAAATCCCCTGCTACGGT , GC percentage: 45
# processing ATGTCTCTTCTTGGGTAGAG , GC percentage: 45
# processing ACTGCCTGTAAACAGTTCAT , GC percentage: 40
# processing TATGCTAGGACTAGACGGGC , GC percentage: 55
# processing CAGTGATCGCGCCCTCTTCG , GC percentage: 65
# processing TAGTTAGTTGTTCGGGTGTA , GC percentage: 40
# processing AGTTTGTCCCTGGGCATATT , GC percentage: 45
# processing TCTAAGAGTATTCTAGCGGT , GC percentage: 40
# processing CCGTGCTGCTCGTCTCCCGA , GC percentage: 70
# processing CACCGCCTGGCCCATCATTA , GC percentage: 60
# processing TTATTTCGTTGAAAACAAAT , GC percentage: 20
# processing GGGGATACAGTTCATGCTTG , GC percentage: 50
# processing CCAAATCGGGGGCTGTTCCA , GC percentage: 60
# processing GTTATGTCTCCTAATGTACA , GC percentage: 35
#
# The sequence with the highest GC value is: GGGGCCCGGTGCCAGGGCGG
# The Highest GC percentage is: 90
# Data written to: output_gc_content.txt
